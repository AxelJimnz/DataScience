# %%
import pandas as pd
import os

# %%
ruta_archivo_excel = 'AD_CL.xlsx'
datos = pd.read_excel(ruta_archivo_excel)

# %%
print(datos.head())
print(datos.describe())
print(datos.isnull().sum())
# Out:
#     E (mV)    i (mA)   E (mV)-20   i (mA)-20   E (mV)-40     i (mA)-40  \
# 0     2.87  0.023956      2870.0     23956.3   2870000.0  2.395630e+10
# 1    16.17  0.026917     16170.0     26916.5  16170000.0  2.691650e+10
# 2    26.15  0.027618     26150.0     27618.4  26150000.0  2.761840e+10
# 3    36.13  0.028564     36130.0     28564.4  36130000.0  2.856440e+10
# 4    46.08  0.028992     46080.0     28991.7  46080000.0  2.899170e+10
#
#       E (mV)-60     i (mA)-60     E (mV)-80     i (mA)-80  ...    E (mV)-600  \
# 0  2.870000e+09  2.395630e+16  2.870000e+12  2.395630e+22  ...  2.870000e+42
# 1  1.617000e+10  2.691650e+16  1.617000e+13  2.691650e+22  ...  1.617000e+43
# 2  2.615000e+10  2.761840e+16  2.615000e+13  2.761840e+22  ...  2.615000e+43
# 3  3.613000e+10  2.856440e+16  3.613000e+13  2.856440e+22  ...  3.613000e+43
# 4  4.608000e+10  2.899170e+16  4.608000e+13  2.899170e+22  ...  4.608000e+43
#
#      i (mA)-600    E (mV)-700    i (mA)-700    E (mV)-800    i (mA)-800  \
# ...

# %%
datos = datos.dropna()
datos.fillna(datos.mean(), inplace=True)
datos = datos.drop_duplicates()

# %%
print(datos)
# Out:
#       E (mV)    i (mA)   E (mV)-20   i (mA)-20   E (mV)-40     i (mA)-40  \
# 0       2.87  0.023956      2870.0     23956.3   2870000.0  2.395630e+10
# 1      16.17  0.026917     16170.0     26916.5  16170000.0  2.691650e+10
# 2      26.15  0.027618     26150.0     27618.4  26150000.0  2.761840e+10
# 3      36.13  0.028564     36130.0     28564.4  36130000.0  2.856440e+10
# 4      46.08  0.028992     46080.0     28991.7  46080000.0  2.899170e+10
# ..       ...       ...         ...         ...         ...           ...
# 337   -39.03  0.031067    -39030.0     31066.9 -39030000.0  3.106690e+10
# 338   -29.05  0.031555    -29050.0     31555.2 -29050000.0  3.155520e+10
# 339   -19.10  0.032043    -19100.0     32043.5 -19100000.0  3.204350e+10
# 340    -9.12  0.032593     -9120.0     32592.8  -9120000.0  3.259280e+10
# 341     0.00  0.000000         0.0         0.0         0.0  0.000000e+00
#
#         E (mV)-60     i (mA)-60     E (mV)-80     i (mA)-80  ...  \
# ...

# %% [markdown]
# CODIFICACION DE VARIABLES CATEGORICAS

# %% [markdown]
# - Utiliza codificación one-hot o de etiquetas

# %%
#data = pd.get_dummies(data, columns=['variable_categorica'])
#datos = pd.get_dummies(datos, columns=['E (mV)', 'i (mA)', 'E (mV)-20', 'i (mA)-20', 'E (mV)-40', 'i (mA)-40', 'E (mV)-60', 'i (mA)-60', 'E (mV)-80', 'i (mA)-80','E (mV)-100', 'i (mA)-100','E (mV)-150', 'i (mA)-150','E (mV)-200', 'i (mA)-200','E (mV)-250', 'i (mA)-250','E (mV)-300', 'i (mA)-300','E (mV)-350', 'i (mA)-350','E (mV)-400', 'i (mA)-400','E (mV)-450', 'i (mA)-450','E (mV)-500', 'i (mA)-500','E (mV)-600', 'i (mA)-600','E (mV)-700', 'i (mA)-700','E (mV)-800', 'i (mA)-800','E (mV)-900', 'i (mA)-900','E (mV)-1000', 'i (mA)-1000'])
datos = pd. read_excel (io = 'ruta_archivo_excel', 
sheet_name= 'AD_CL', header=0, names = None, index_col = None,
usecols =  'A:AL',engine='openpyx1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\axel_\OneDrive\Documentos\ICO - AXEL JIMENEZ PEREZ\SEXTO SEMESTRE\CIENCIA DE DATOS\proyecto\Ciencia_de_Datos\datos\analisis.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/axel_/OneDrive/Documentos/ICO%20-%20AXEL%20JIMENEZ%20PEREZ/SEXTO%20SEMESTRE/CIENCIA%20DE%20DATOS/proyecto/Ciencia_de_Datos/datos/analisis.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> #data = pd.get_dummies(data, columns=['variable_categorica'])
# ...
